# %% [markdown]
# ## Protein Dataset Preperation

# %%
import pandas as pd
import numpy

#import data sets in meth data
df=pd.read_csv('HumanMethylation450_selected_200.csv').set_index('Unnamed: 0')
features=pd.read_csv('best_60_features.csv',header=None).T

# %%
df=df[features.to_numpy()[0]]

# %%
df.to_csv('methylation.csv', sep='\t')

# %%
df4=pd.read_csv('methylation.csv',sep='\t').set_index('Unnamed: 0')

# %%
df4
# Out:
#                  cg0586019  cg1735603  cg1220237  cg0267012  cg0626228  \
# Unnamed: 0
# TCGA-CZ-4863-01     0.6496     0.7435     0.7495     0.7067     0.7693
# TCGA-CJ-4904-11     0.5319     0.5864     0.6044     0.4939     0.5833
# TCGA-B0-4827-11     0.6877     0.6717     0.6553     0.6474     0.6712
# TCGA-CJ-4902-01     0.3654     0.7259     0.5805     0.6108     0.5368
# TCGA-B0-4823-01     0.6636     0.6254     0.4809     0.7846     0.8367
# ...                    ...        ...        ...        ...        ...
# TCGA-KL-8333-01     0.4120     0.5695     0.6005     0.3014     0.3872
# TCGA-KL-8329-01     0.1997     0.6762     0.2523     0.1134     0.3294
# TCGA-KL-8338-01     0.1413     0.4033     0.2752     0.0536     0.2173
# TCGA-KN-8433-01     0.1704     0.4191     0.4589     0.1122     0.3077
# TCGA-KN-8431-01     0.0662     0.3024     0.3725     0.0539     0.1292
#
#                  cg0967733  cg2423367  cg2628069  cg1260869  cg2645004  ...  \
# ...
